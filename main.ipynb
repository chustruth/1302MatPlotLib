# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
crox = np.array([  0,      1,      2,      3,      14])
croy = np.array([  0.48,   0.489,  0.4903, 0.4914, 0.5017])

croy2 = np.array([  0.481,   0.482,  0.4913, 0.4984, 0.5117])

tusdx = np.array([  0,      1,      2,      3,      14])
tusdy = np.array([  1.00,   0.99,  1.01, 1.00, 1.01])
 # CRONOS COIN
 # AT TIME
plt.plot(crox, croy) 
plt.subplot(2,1,1)

plt.plot(crox, croy2) 
plt.subplot(2,1,2)

plt.show()
